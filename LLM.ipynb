# %%
import streamlit as st
from langchain.llms import OpenAI
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import streamlit as st
#       2 from langchain.llms import OpenAI
#
# ModuleNotFoundError: No module named 'streamlit'

# %%
# %pip install streamlit 
# from langchain.llms import OpenAI
# Out:
# Collecting streamlit
#   Using cached streamlit-1.37.1-py2.py3-none-any.whl.metadata (8.5 kB)
# Collecting altair<6,>=4.0 (from streamlit)
#   Using cached altair-5.4.0-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from streamlit) (1.8.2)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from streamlit) (5.4.0)
# Requirement already satisfied: click<9,>=7.0 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<3,>=1.20 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from streamlit) (2.0.1)
# Requirement already satisfied: packaging<25,>=20 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from streamlit) (24.1)
# Requirement already satisfied: pandas<3,>=1.3.0 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<11,>=7.1.0 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from streamlit) (10.4.0)
# Requirement already satisfied: protobuf<6,>=3.20 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from streamlit) (5.27.3)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from streamlit) (17.0.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from streamlit) (2.32.3)
# Collecting rich<14,>=10.14.0 (from streamlit)
#   Using cached rich-13.7.1-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: tenacity<9,>=8.1.0 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from streamlit) (8.5.0)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from streamlit) (4.12.2)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit)
#   Using cached GitPython-3.1.43-py3-none-any.whl.metadata (13 kB)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Using cached pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from streamlit) (6.4.1)
# Requirement already satisfied: watchdog<5,>=2.1.5 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from streamlit) (4.0.2)
# Collecting jinja2 (from altair<6,>=4.0->streamlit)
#   Using cached jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
# Collecting jsonschema>=3.0 (from altair<6,>=4.0->streamlit)
#   Using cached jsonschema-4.23.0-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: narwhals>=1.1.0 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from altair<6,>=4.0->streamlit) (1.3.0)
# Requirement already satisfied: colorama in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Using cached gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from requests<3,>=2.27->streamlit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from requests<3,>=2.27->streamlit) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from requests<3,>=2.27->streamlit) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from requests<3,>=2.27->streamlit) (2024.7.4)
# Collecting markdown-it-py>=2.2.0 (from rich<14,>=10.14.0->streamlit)
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.18.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (24.2.0)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema>=3.0->altair<6,>=4.0->streamlit)
#   Using cached jsonschema_specifications-2023.12.1-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.20.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.3.0->streamlit) (1.16.0)
# Using cached streamlit-1.37.1-py2.py3-none-any.whl (8.7 MB)
# Using cached altair-5.4.0-py3-none-any.whl (671 kB)
# Using cached GitPython-3.1.43-py3-none-any.whl (207 kB)
# Using cached pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
# Using cached rich-13.7.1-py3-none-any.whl (240 kB)
# Using cached gitdb-4.0.11-py3-none-any.whl (62 kB)
# Using cached jinja2-3.1.4-py3-none-any.whl (133 kB)
# Using cached jsonschema-4.23.0-py3-none-any.whl (88 kB)
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Using cached jsonschema_specifications-2023.12.1-py3-none-any.whl (18 kB)
# Installing collected packages: markdown-it-py, jinja2, gitdb, rich, pydeck, jsonschema-specifications, gitpython, jsonschema, altair, streamlit
# Successfully installed altair-5.4.0 gitdb-4.0.11 gitpython-3.1.43 jinja2-3.1.4 jsonschema-4.23.0 jsonschema-specifications-2023.12.1 markdown-it-py-3.0.0 pydeck-0.9.1 rich-13.7.1 streamlit-1.37.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install langchain
# Out:
# Collecting langchain
#   Using cached langchain-0.2.12-py3-none-any.whl.metadata (7.1 kB)
# Collecting PyYAML>=5.3 (from langchain)
#   Downloading PyYAML-6.0.2-cp312-cp312-win_amd64.whl.metadata (2.1 kB)
# Collecting SQLAlchemy<3,>=1.4 (from langchain)
#   Using cached SQLAlchemy-2.0.32-cp312-cp312-win_amd64.whl.metadata (9.8 kB)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain)
#   Using cached aiohttp-3.10.3-cp312-cp312-win_amd64.whl.metadata (7.8 kB)
# Collecting langchain-core<0.3.0,>=0.2.27 (from langchain)
#   Using cached langchain_core-0.2.29-py3-none-any.whl.metadata (6.2 kB)
# Collecting langchain-text-splitters<0.3.0,>=0.2.0 (from langchain)
#   Using cached langchain_text_splitters-0.2.2-py3-none-any.whl.metadata (2.1 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain)
#   Using cached langsmith-0.1.99-py3-none-any.whl.metadata (13 kB)
# Collecting numpy<2.0.0,>=1.26.0 (from langchain)
#   Using cached numpy-1.26.4-cp312-cp312-win_amd64.whl.metadata (61 kB)
# Collecting pydantic<3,>=1 (from langchain)
#   Using cached pydantic-2.8.2-py3-none-any.whl.metadata (125 kB)
# Requirement already satisfied: requests<3,>=2 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from langchain) (8.5.0)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Using cached aiohappyeyeballs-2.3.5-py3-none-any.whl.metadata (5.8 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Using cached aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.2.0)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Using cached frozenlist-1.4.1-cp312-cp312-win_amd64.whl.metadata (12 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Using cached multidict-6.0.5-cp312-cp312-win_amd64.whl.metadata (4.3 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Using cached yarl-1.9.4-cp312-cp312-win_amd64.whl.metadata (32 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<0.3.0,>=0.2.27->langchain)
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from langchain-core<0.3.0,>=0.2.27->langchain) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from langchain-core<0.3.0,>=0.2.27->langchain) (4.12.2)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.2.0,>=0.1.17->langchain)
#   Using cached orjson-3.10.7-cp312-none-win_amd64.whl.metadata (51 kB)
# Collecting annotated-types>=0.4.0 (from pydantic<3,>=1->langchain)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.20.1 (from pydantic<3,>=1->langchain)
#   Using cached pydantic_core-2.20.1-cp312-none-win_amd64.whl.metadata (6.7 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from requests<3,>=2->langchain) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from requests<3,>=2->langchain) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from requests<3,>=2->langchain) (2024.7.4)
# Collecting greenlet!=0.4.17 (from SQLAlchemy<3,>=1.4->langchain)
#   Using cached greenlet-3.0.3-cp312-cp312-win_amd64.whl.metadata (3.9 kB)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.27->langchain)
#   Using cached jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Using cached langchain-0.2.12-py3-none-any.whl (990 kB)
# Using cached aiohttp-3.10.3-cp312-cp312-win_amd64.whl (377 kB)
# Using cached langchain_core-0.2.29-py3-none-any.whl (383 kB)
# Using cached langchain_text_splitters-0.2.2-py3-none-any.whl (25 kB)
# Using cached langsmith-0.1.99-py3-none-any.whl (140 kB)
# Using cached numpy-1.26.4-cp312-cp312-win_amd64.whl (15.5 MB)
# Using cached pydantic-2.8.2-py3-none-any.whl (423 kB)
# Using cached pydantic_core-2.20.1-cp312-none-win_amd64.whl (1.9 MB)
# Downloading PyYAML-6.0.2-cp312-cp312-win_amd64.whl (156 kB)
# Using cached SQLAlchemy-2.0.32-cp312-cp312-win_amd64.whl (2.1 MB)
# Using cached aiohappyeyeballs-2.3.5-py3-none-any.whl (12 kB)
# Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached frozenlist-1.4.1-cp312-cp312-win_amd64.whl (50 kB)
# Using cached greenlet-3.0.3-cp312-cp312-win_amd64.whl (293 kB)
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Using cached multidict-6.0.5-cp312-cp312-win_amd64.whl (27 kB)
# Using cached orjson-3.10.7-cp312-none-win_amd64.whl (137 kB)
# Using cached yarl-1.9.4-cp312-cp312-win_amd64.whl (76 kB)
# Using cached jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Installing collected packages: PyYAML, pydantic-core, orjson, numpy, multidict, jsonpointer, greenlet, frozenlist, annotated-types, aiohappyeyeballs, yarl, SQLAlchemy, pydantic, jsonpatch, aiosignal, langsmith, aiohttp, langchain-core, langchain-text-splitters, langchain
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.1
#     Uninstalling numpy-2.0.1:
#       Successfully uninstalled numpy-2.0.1
# Successfully installed PyYAML-6.0.2 SQLAlchemy-2.0.32 aiohappyeyeballs-2.3.5 aiohttp-3.10.3 aiosignal-1.3.1 annotated-types-0.7.0 frozenlist-1.4.1 greenlet-3.0.3 jsonpatch-1.33 jsonpointer-3.0.0 langchain-0.2.12 langchain-core-0.2.29 langchain-text-splitters-0.2.2 langsmith-0.1.99 multidict-6.0.5 numpy-1.26.4 orjson-3.10.7 pydantic-2.8.2 pydantic-core-2.20.1 yarl-1.9.4
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install streamlit openai langchain
# Out:
# Requirement already satisfied: streamlit in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (1.37.1)
# Collecting openai
#   Using cached openai-1.40.3-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: langchain in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (0.2.12)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from streamlit) (5.4.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from streamlit) (1.8.2)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from streamlit) (5.4.0)
# Requirement already satisfied: click<9,>=7.0 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<3,>=1.20 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging<25,>=20 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from streamlit) (24.1)
# Requirement already satisfied: pandas<3,>=1.3.0 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<11,>=7.1.0 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from streamlit) (10.4.0)
# Requirement already satisfied: protobuf<6,>=3.20 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from streamlit) (5.27.3)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from streamlit) (17.0.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from streamlit) (2.32.3)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from streamlit) (13.7.1)
# Requirement already satisfied: tenacity<9,>=8.1.0 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from streamlit) (8.5.0)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from streamlit) (4.12.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from streamlit) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from streamlit) (6.4.1)
# Requirement already satisfied: watchdog<5,>=2.1.5 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from streamlit) (4.0.2)
# Collecting anyio<5,>=3.5.0 (from openai)
#   Using cached anyio-4.4.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting distro<2,>=1.7.0 (from openai)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Using cached httpx-0.27.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting jiter<1,>=0.4.0 (from openai)
#   Using cached jiter-0.5.0-cp312-none-win_amd64.whl.metadata (3.7 kB)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from openai) (2.8.2)
# Collecting sniffio (from openai)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting tqdm>4 (from openai)
#   Using cached tqdm-4.66.5-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from langchain) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from langchain) (2.0.32)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from langchain) (3.10.3)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.27 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from langchain) (0.2.29)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from langchain) (0.2.2)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from langchain) (0.1.99)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.3.5)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Requirement already satisfied: jinja2 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: narwhals>=1.1.0 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from altair<6,>=4.0->streamlit) (1.3.0)
# Requirement already satisfied: idna>=2.8 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: colorama in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.11)
# Requirement already satisfied: certifi in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from httpx<1,>=0.23.0->openai) (2024.7.4)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai)
#   Using cached httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai)
#   Using cached h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from langchain-core<0.3.0,>=0.2.27->langchain) (1.33)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2024.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from requests<3,>=2.27->streamlit) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from requests<3,>=2.27->streamlit) (2.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.18.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.5)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.27->langchain) (3.0.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.20.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.3.0->streamlit) (1.16.0)
# Using cached openai-1.40.3-py3-none-any.whl (360 kB)
# Using cached anyio-4.4.0-py3-none-any.whl (86 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached httpx-0.27.0-py3-none-any.whl (75 kB)
# Using cached httpcore-1.0.5-py3-none-any.whl (77 kB)
# Using cached jiter-0.5.0-cp312-none-win_amd64.whl (189 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Using cached tqdm-4.66.5-py3-none-any.whl (78 kB)
# Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Installing collected packages: tqdm, sniffio, jiter, h11, distro, httpcore, anyio, httpx, openai
# Successfully installed anyio-4.4.0 distro-1.9.0 h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 jiter-0.5.0 openai-1.40.3 sniffio-1.3.1 tqdm-4.66.5
# Note: you may need to restart the kernel to use updated packages.

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 2
#       1 import streamlit as st
# ----> 2 from langchain.llms import OpenAI
#       4 st.title('🦜🔗 Quickstart App')
#       6 openai_api_key = st.sidebar.text_input('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')
#
# File c:\Users\RCPIT\Desktop\LLM\.venv\Lib\site-packages\langchain\llms\__init__.py:545, in __getattr__(name)
#     544 def __getattr__(name: str) -> Any:
# --> 545     from langchain_community import llms
#     547     # If not in interactive env, raise warning.
#     548     if not is_interactive_env():
#
# ModuleNotFoundError: No module named 'langchain_community'

# %%
# %pip install langchain_community
# Out:
# Collecting langchain_community
#   Downloading langchain_community-0.2.11-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from langchain_community) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from langchain_community) (2.0.32)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from langchain_community) (3.10.3)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain_community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: langchain<0.3.0,>=0.2.12 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from langchain_community) (0.2.12)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.27 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from langchain_community) (0.2.29)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from langchain_community) (0.1.99)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from langchain_community) (1.26.4)
# Requirement already satisfied: requests<3,>=2 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from langchain_community) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from langchain_community) (8.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.3.5)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.9.4)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain_community)
#   Downloading marshmallow-3.21.3-py3-none-any.whl.metadata (7.1 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain_community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from langchain<0.3.0,>=0.2.12->langchain_community) (0.2.2)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from langchain<0.3.0,>=0.2.12->langchain_community) (2.8.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from langchain-core<0.3.0,>=0.2.27->langchain_community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from langchain-core<0.3.0,>=0.2.27->langchain_community) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from langchain-core<0.3.0,>=0.2.27->langchain_community) (4.12.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain_community) (3.10.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from requests<3,>=2->langchain_community) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from requests<3,>=2->langchain_community) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from requests<3,>=2->langchain_community) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from requests<3,>=2->langchain_community) (2024.7.4)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain_community) (3.0.3)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.27->langchain_community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.12->langchain_community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\rcpit\desktop\llm\.venv\lib\site-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.12->langchain_community) (2.20.1)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Downloading langchain_community-0.2.11-py3-none-any.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    --------- ------------------------------ 0.5/2.3 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 8.1 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading marshmallow-3.21.3-py3-none-any.whl (49 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: mypy-extensions, marshmallow, typing-inspect, dataclasses-json, langchain_community
# Successfully installed dataclasses-json-0.6.7 langchain_community-0.2.11 marshmallow-3.21.3 mypy-extensions-1.0.0 typing-inspect-0.9.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import streamlit as st
from langchain.llms import OpenAI

st.title('🦜🔗 Quickstart App')

openai_api_key = st.sidebar.text_input('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')

def generate_response(input_text):
  llm = OpenAI(temperature=0.7, openai_api_key=openai_api_key)
  st.info(llm(input_text))

with st.form('my_form'):
  text = st.text_area('Enter text:', 'What are the three key pieces of advice for learning how to code?')
  submitted = st.form_submit_button('Submit')
  if not openai_api_key.startswith('sk-'):
    st.warning('Please enter your OpenAI API key!', icon='⚠')
  if submitted and openai_api_key.startswith('sk-'):
    generate_response(text)
# Out:
# 2024-08-12 14:40:23.740
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run c:\Users\RCPIT\Desktop\LLM\.venv\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2024-08-12 14:40:23.740 Session state does not function when running a script without `streamlit run`
